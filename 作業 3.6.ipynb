# %%
import numpy as np
# %matplotlib inline
from scipy.optimize import curve_fit 
from sklearn.cross_validation import train_test_split

# %%
import matplotlib.pyplot as plt

# %%
x = np.linspace(0,20,300)

# %%
y = 2*x +3 + np.random.randn(300)

# %%
def f(x,a,b):
    return a*x + b

# %%
popt, pcov = curve_fit(f,x,y)

# %%
a,b = popt

# %%
from sklearn.cross_validation import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state=101)

# %%
popt, pcov = curve_fit(f,x_train,y_train)

# %%
a,b = popt # 訓練結果

# %%
plt.figure(figsize=(15,9))

plt.scatter(x_test,y_test,s=30)

plt.plot(np.sort(x_test), np.sort(a*x_test +b),c="g")
plt.plot(np.sort(x_train), np.sort(a*x_train +b),c="r",alpha=0.2 )

# %%
x_test,y_test
# Out:
# (array([ 1.61616162,  0.1010101 ,  4.34343434,  6.76767677,  8.98989899,
#          2.12121212,  9.7979798 ,  5.15151515,  0.60606061,  4.14141414,
#          8.28282828,  2.52525253,  4.54545455,  6.86868687,  3.73737374,
#          3.13131313,  5.05050505,  3.23232323,  0.3030303 ,  4.84848485]),
#  array([  4.86641863,   3.2876784 ,  11.27179217,  17.35802078,
#          21.69657102,   8.09077577,  23.27671469,  12.8268269 ,
#           5.18540838,  11.89247621,  19.62098372,   6.29753832,
#          14.11056275,  17.52542374,   9.52344749,   8.8714598 ,
#          12.6570628 ,   9.87923833,   2.81492164,  12.15750178]))

# %%
np.sort(x_test),np.sort(y_test)
# Out:
# (array([ 0.1010101 ,  0.3030303 ,  0.60606061,  1.61616162,  2.12121212,
#          2.52525253,  3.13131313,  3.23232323,  3.73737374,  4.14141414,
#          4.34343434,  4.54545455,  4.84848485,  5.05050505,  5.15151515,
#          6.76767677,  6.86868687,  8.28282828,  8.98989899,  9.7979798 ]),
#  array([  2.81492164,   3.2876784 ,   4.86641863,   5.18540838,
#           6.29753832,   8.09077577,   8.8714598 ,   9.52344749,
#           9.87923833,  11.27179217,  11.89247621,  12.15750178,
#          12.6570628 ,  12.8268269 ,  14.11056275,  17.35802078,
#          17.52542374,  19.62098372,  21.69657102,  23.27671469]))
